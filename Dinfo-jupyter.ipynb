# %% [markdown]
# # Tokyo Disney Resort Information

# %%
from selenium import webdriver
import os
import time
import random
import pandas as pd

class TDRScrapy:
 
    def __init__(self, default_wait=5):
        self.default_wait = default_wait
        self.driver = None
        self.realtimeinfo = pd.DataFrame(columns=["Title", "URL", "WaitingTime", "Fastpass", "FastpassTime", "Operation", "OperationTime"])


    def openHP(self, park):
        print("---"*20)
        print("Loading " + park + " Realtime")
        
        url = "https://www.tokyodisneyresort.jp/" + park + "/realtime.html"
        
        self.driver.get(url)
        
        random_latitude = 35.622908 + (35.630000 - 35.622908) * random.random()
        random_longitude = 139.872945 + (139.890000 - 139.872945) * random.random()
        
#         print("Random_Latitude : ", random_latitude)
#         print("Random_Longitude : ", random_longitude)
        
        self.driver.execute_script("window.navigator.geolocation.getCurrentPosition=function(success){"
                              + "var position = {\"coords\" : {\"latitude\": \"" + str(random_latitude) + "\",\"longitude\": \"" + str(random_longitude) + "\"}};"
                              + "success(position);}")

        print(self.driver.execute_script("var positionStr=\"\";"
                                    + "window.navigator.geolocation.getCurrentPosition(function(pos){positionStr=\"lat:\"+pos.coords.latitude+\", long:\"+pos.coords.longitude});"
                                    + "return positionStr;"))


        self.driver.find_element_by_id('gpsButton').click()

    def getWaitingTime(self):

        all_search = self.driver.find_elements_by_class_name('listItem')
        for data in all_search:
            title = data.find_element_by_tag_name('h3').text
            url = data.find_element_by_css_selector('a').get_attribute('href')

            try:
                waitingtime = data.find_element_by_class_name('time').text
            except:
                try:
                    waitingtime = data.find_element_by_class_name('waitingTime').text
                except:
                    waitingtime = "-"
                    
            
            # fastpass
            try:
                fastpass = data.find_element_by_class_name('fastpass').text
                fastpasstime = data.find_element_by_class_name('fastpassTime').text
            except:
                try:
                    fastpass = data.find_element_by_class_name('fastpass_end').text
                    fastpasstime = "-"
                except:
                    fastpass = ""
                    fastpasstime = ""
            
            try:
                operationtime = data.find_element_by_class_name('operationTime').text
                operation = data.find_element_by_class_name('operation').text
            except:
                try:
                    operationtime = "-"
                    operation = data.find_element_by_class_name('operation').text
                except:
                    operationtime = "-"
                    operation = data.find_element_by_class_name('timeTable').text
                
            tmpinfo = [[title, url, waitingtime, fastpass, fastpasstime, operation, operationtime]]
            print("list:", tmpinfo)
            
            self.realtimeinfo = self.realtimeinfo.append(tmpinfo, ignore_index=True)
            self.realtimeinfo

    def start(self, park):
        if os.name == 'nt':
            self.driver = webdriver.Chrome("C:/Users/mchan/Desktop/GoogleSearchIndex-python/Driver/chromedriver_win")
        else:
            self.driver = webdriver.Chrome('C:/Users/mchan/Desktop/GoogleSearchIndex-python/Driver/chromedriver')
        
        self.driver.implicitly_wait(self.default_wait)
        
        self.openHP(park)
        self.getWaitingTime()
#         self.driver.quit()





tdr = TDRScrapy()

tdr.start("tdl")
tdr.start("tds")
# Out:
# ------------------------------------------------------------
# Loading tdl Realtime
# lat:35.629342292877325, long:139.87736090081083
# list: [['オムニバス', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/151/', '-', '', '', '案内終了', '8:30 – 18:30']]
# C:\Users\mchan\Anaconda3\lib\site-packages\pandas\core\indexes\api.py:107: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)
# list: [['ペニーアーケード', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/191/', '待ち時間は施設でご確認ください。', '', '', '運営中', '8:00 – 22:00']]
# C:\Users\mchan\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# list: [['ウエスタンリバー鉄道', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/154/', '10', '', '', '運営中', '8:00 – 22:00']]
# list: [['カリブの海賊', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/152/', '5', '', '', '運営中', '8:00 – 22:00']]
# list: [['ジャングルクルーズ：ワイルドライフ・エクスペディション', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/153/', '10', '', '', '運営中', '8:00 – 22:00']]
# list: [['スイスファミリー・ツリーハウス', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/155/', '0', '', '', '運営中', '9:00 – 21:00']]
# list: [['魅惑のチキルーム：スティッチ・プレゼンツ〝アロハ・エ・コモ・マイ！〝', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/156/', '5', '', '', '運営中', '9:00 – 21:00']]
# list: [['ウエスタンランド・シューティングギャラリー', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/157/', '5', '', '', '運営中', '8:00 – 22:00']]
# list: [['カントリーベア・シアター', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/158/', '5', '', '', '運営中', '9:00 – 21:00']]
# list: [['トムソーヤ島いかだ', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/161/', '-', '', '', '案内終了', '9:00 – 18:15']]
# list: [['ビッグサンダー・マウンテン', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/160/', '50', '発券終了', '-', '運営中', '8:00 – 22:00']]
# list: [['蒸気船マークトウェイン号', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/159/', '10', '', '', '運営中', '9:00 – 22:00']]
# list: [['スプラッシュ・マウンテン', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/162/', '45', '発券終了', '-', '運営中', '8:00 – 22:00']]
# list: [['ビーバーブラザーズのカヌー探険', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/163/', '-', '', '', '案内終了', '9:00 – 18:30']]
# list: [['アリスのティーパーティー', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/173/', '5', '', '', '運営中', '8:00 – 22:00']]
# list: [['イッツ・ア・スモールワールド', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/172/', '15', '発券終了', '-', '運営中', '8:00 – 22:00']]
# list: [['キャッスルカルーセル', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/170/', '15', '', '', '運営中', '8:00 – 22:00']]
# list: [['シンデレラのフェアリーテイル・ホール', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/166/', '-', '', '', '案内終了', '8:00 – 20:00']]
# list: [['ピノキオの冒険旅行', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/168/', '5', '', '', '運営中', '8:00 – 22:00']]
# list: [['ピーターパン空の旅', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/164/', '25', '', '', '運営中', '8:00 – 22:00']]
# list: [['プーさんのハニーハント', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/174/', '40', '発券終了', '-', '運営中', '8:00 – 22:00']]
# list: [['ホーンテッドマンション', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/171/', '13', '発券終了', '-', '運営中', '8:00 – 22:00']]
# list: [['ミッキーのフィルハーマジック', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/167/', '10', '', '', '運営中', '8:00 – 22:00']]
# list: [['白雪姫と七人のこびと', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/165/', '10', '', '', '運営中', '8:00 – 22:00']]
# list: [['空飛ぶダンボ', 'https://www.tokyodisneyresort.jp/tdl/attraction/detail/169/', '20', '', '', '運営中', '8:00 – 22:00']]
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-1-17eadf73a364> in getWaitingTime(self)
#      68             try:
# ---> 69                 operationtime = data.find_element_by_class_name('operationTime').text
#      70                 operation = data.find_element_by_class_name('operation').text
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_class_name(self, name)
#     397         """
# --> 398         return self.find_element(by=By.CLASS_NAME, value=name)
#     399
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     653         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 654                              {"using": by, "value": value})['value']
#     655
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=67.0.3396.99)
#   (Driver info: chromedriver=2.40.565498 (ea082db3280dd6843ebfb08a625e3eb905c4f5ab),platform=Windows NT 10.0.17134 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-1-17eadf73a364> in getWaitingTime(self)
#      73                     operationtime = "-"
# ---> 74                     operation = data.find_element_by_class_name('operation').text
#      75                 except:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_class_name(self, name)
#     397         """
# --> 398         return self.find_element(by=By.CLASS_NAME, value=name)
#     399
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     653         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 654                              {"using": by, "value": value})['value']
#     655
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=67.0.3396.99)
#   (Driver info: chromedriver=2.40.565498 (ea082db3280dd6843ebfb08a625e3eb905c4f5ab),platform=Windows NT 10.0.17134 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-1-17eadf73a364> in <module>()
#     101 tdr = TDRScrapy()
#     102
# --> 103 tdr.start("tdl")
#     104 tdr.start("tds")
#
# <ipython-input-1-17eadf73a364> in start(self, park)
#      92
#      93         self.openHP(park)
# ---> 94         self.getWaitingTime()
#      95 #         self.driver.quit()
#      96
#
# <ipython-input-1-17eadf73a364> in getWaitingTime(self)
#      75                 except:
#      76                     operationtime = "-"
# ---> 77                     operation = data.find_element_by_class_name('timeTable').text
#      78
#      79             tmpinfo = [[title, url, waitingtime, fastpass, fastpasstime, operation, operationtime]]
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_class_name(self, name)
#     396             element = element.find_element_by_class_name('foo')
#     397         """
# --> 398         return self.find_element(by=By.CLASS_NAME, value=name)
#     399
#     400     def find_elements_by_class_name(self, name):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     652
#     653         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 654                              {"using": by, "value": value})['value']
#     655
#     656     def find_elements(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     626             params = {}
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#     630     def find_element(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#     322                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=67.0.3396.99)
#   (Driver info: chromedriver=2.40.565498 (ea082db3280dd6843ebfb08a625e3eb905c4f5ab),platform=Windows NT 10.0.17134 x86_64)
